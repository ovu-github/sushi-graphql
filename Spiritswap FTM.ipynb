# %%
# https://k3no.medium.com/how-to-query-in-graphql-6ebb3f7085dc
# https://github.com/sushiswap/sushiswap-subgraph

# %%
from gql import gql, Client
from gql.transport.requests import RequestsHTTPTransport
import pandas as pd
import dataframe_image as dfi
import os

fantom = 'https://api.thegraph.com/subgraphs/name/layer3org/spiritswap-analytics'
# https://thegraph.com/explorer/subgraph/eerieeight/spooky-swap-exchange

# %% [markdown]
# ## Fantom

# %%
sample_transport=RequestsHTTPTransport(
    url=fantom,
    verify=True,
    retries=3,
)

client = Client(transport=sample_transport)

query = gql('''
query {
  spiritswapFactories{
    pairCount
  }
}
''')

response = client.execute(query)
number_of_pairs = int(response['spiritswapFactories'][0]['pairCount'])
print(number_of_pairs)
# Out:
# 620

# %%
token0list = []
token1list = []
id_list = []

for i in range(number_of_pairs):
    if i % 100 == 0:
        querystring = '''
              query {
              pairs(first: '''+str(100)+' skip: '+str(i)+''' where: {volumeUSD_gt:0}){
                      token0{symbol}
                      token1{symbol}
                      id
                  }
                }
                '''
        response = client.execute(gql(querystring))
        for row in response['pairs']:
            token0list.append(row['token0']['symbol'])
            token1list.append(row['token1']['symbol'])
            id_list.append(row['id'])    

df_spirit = pd.DataFrame.from_dict(list(zip(token0list,token1list,id_list)))
df_spirit.columns = ['Token 0', 'Token 1', 'id']
df_spirit['Pair'] = df_spirit['Token 0'] + '-' + df_spirit['Token 1']
df_spirit = df_spirit[['Pair', 'id', 'Token 0', 'Token 1']]
df_spirit
# Out:
#                 Pair                                          id Token 0  \
# 0          USDC-BUSD  0x0070b5c2329103a5c278a0f3e8c248f1b706b4a8    USDC
# 1    WFTM-SafeFantom  0x0134fae8f2bc78a901eadb7a0366ac03a2144fd0    WFTM
# 2          WFTM-PILE  0x027ce309cad438ba200c1972f76afd08b458dcd5    WFTM
# 3         WFTM-KINGS  0x030df16a8d38444d13e633da564e62ea71899845    WFTM
# 4           WFTM-GOV  0x03b36c0790a84c6382c4afda7584107c6522f97e    WFTM
# ..               ...                                         ...     ...
# 343        WFTM-Saaa  0xfa7558260ecdc0c0473e836db600b667e94ecc7d    WFTM
# 344       ALICE-WFTM  0xfcef3df7edf4789d35b63554d24b64faafa14ebe   ALICE
# 345          USDC-VW  0xfe7f8c6a0c0feca36d644a4e100728463a276534    USDC
# 346        WFTM-IODN  0xff9f2d6ac0e4e3367064cc376754e302d8ac2f82    WFTM
# 347       SPIRIT-DAI  0xffbfc0446ca725b21256461e214e9d472f9be390  SPIRIT
#
#         Token 1
# 0          BUSD
# 1    SafeFantom
# 2          PILE
# 3         KINGS
# 4           GOV
# ..          ...
# 343        Saaa
# 344        WFTM
# 345          VW
# 346        IODN
# 347         DAI
#
# [348 rows x 4 columns]

# %%
cream_borrowing_tokens = ['USDC', 'WFTM', 'DAI', 'ETH', 'BTC', 'LINK', 'SUSHI',\
'YFI',
'SNX',
'BAND',
'AAVE',
'COVER',
'CREAM',
'HEGIC']

interesting_tokens = ['WFTM', 'USDC', 'DAI', 'FUSD', 'ETH', 'fUSDT', 'FETH', 'WBTC']
combined_tokens = cream_borrowing_tokens + interesting_tokens
combined_tokens
# Out:
# ['USDC',
#  'WFTM',
#  'DAI',
#  'ETH',
#  'BTC',
#  'LINK',
#  'SUSHI',
#  'YFI',
#  'SNX',
#  'BAND',
#  'AAVE',
#  'COVER',
#  'CREAM',
#  'HEGIC',
#  'WFTM',
#  'USDC',
#  'DAI',
#  'FUSD',
#  'ETH',
#  'fUSDT',
#  'FETH',
#  'WBTC']

# %%
criteria = df_spirit['Token 0'].isin(combined_tokens) & \
           df_spirit['Token 1'].isin(combined_tokens)

df_spirit_filtered = df_spirit.loc[criteria,:]
df_spirit_filtered.columns = ['Pair', 'id', 'Token 0', 'Token 1']
df_spirit_filtered
# Out:
#            Pair                                          id Token 0 Token 1
# 5    WFTM-CREAM  0x040dd0d0f5e2a01feb0c5457abb588b23cf4c43a    WFTM   CREAM
# 56     WFTM-BTC  0x279b2c897737a50405ed2091694f225d83f2d3ba    WFTM     BTC
# 71     WFTM-SNX  0x33068ad825fbeedb0e57e0466e379290b699f57c    WFTM     SNX
# 91     USDC-ETH  0x4556f6afa9b016a83052d459290573a5d83c8764    USDC     ETH
# 100    WFTM-YFI  0x4fc38a2735c7da1d71ccabf6dec235a7da4ec52c    WFTM     YFI
# 108  WFTM-COVER  0x5427e7ab61145c41b1e58453121245daef3929c3    WFTM   COVER
# 128    WFTM-ETH  0x613bf4e46b4817015c01c6bb31c7ae9edaadc26e    WFTM     ETH
# 137   USDC-FUSD  0x679449a920087828776aeef4074549410d5c8065    USDC    FUSD
# 145    USDC-BTC  0x6d134d63417dc67f57dbc9fcaad4b4cbfab3af2f    USDC     BTC
# 149    WFTM-ETH  0x6d87359b1e3fd852bd36250018e3328d1afd78e7    WFTM     ETH
# 206    USDC-DAI  0x9606d683d03f012dda296ef0ae9261207c4a5847    USDC     DAI
# 211    DAI-FUSD  0x98c8cc0e444ce7490926a6c58484b937cf60e117     DAI    FUSD
# 223  WFTM-SUSHI  0x9fe4c0ce5f533e96c2b72d852f190961ad5a7bb3    WFTM   SUSHI
# 258   WFTM-FUSD  0xbaf1b2fd16f7294ca158b3f1065e5f27f9c72b61    WFTM    FUSD
# 286   WFTM-LINK  0xd061c6586670792331e14a80f3b3bb267189c681    WFTM    LINK
# 287  fUSDT-WFTM  0xd14dd3c56d9bc306322d4cea0e1c49e9ddf045d4   fUSDT    WFTM
# 292   fUSDT-DAI  0xd3a0c65e5cefcee01fe2b10d04e7c16ea36974de   fUSDT     DAI
# 304    WFTM-DAI  0xdbc490b47508d31c9ec44afb6e132ad01c61a02c    WFTM     DAI
# 319   USDC-WFTM  0xe7e90f5a767406eff87fdad7eb07ef407922ec1d    USDC    WFTM

# %%
df4 = pd.DataFrame([])
lenid = len(df_spirit_filtered['id'])

client = Client(transport=sample_transport)

for count, id in enumerate(df_spirit_filtered['id']):
    print(f'{count+1:2} / {lenid} pair: {id}')
        
    querystring = '''
              query {
  pairDayDatas(where: {pairAddress:"''' + id + '''"} orderBy: date, orderDirection: desc first: 7) {
    date
    dailyVolumeUSD
    reserveUSD
  }
}'''
    response = client.execute(gql(querystring))
    response
    
    df1 = pd.DataFrame.from_dict(response['pairDayDatas'])
    df1['id'] = id
    df4 = df4.append(df1)
    
df4
# Out:
#  1 / 19 pair: 0x040dd0d0f5e2a01feb0c5457abb588b23cf4c43a
#  2 / 19 pair: 0x279b2c897737a50405ed2091694f225d83f2d3ba
#  3 / 19 pair: 0x33068ad825fbeedb0e57e0466e379290b699f57c
#  4 / 19 pair: 0x4556f6afa9b016a83052d459290573a5d83c8764
#  5 / 19 pair: 0x4fc38a2735c7da1d71ccabf6dec235a7da4ec52c
#  6 / 19 pair: 0x5427e7ab61145c41b1e58453121245daef3929c3
#  7 / 19 pair: 0x613bf4e46b4817015c01c6bb31c7ae9edaadc26e
#  8 / 19 pair: 0x679449a920087828776aeef4074549410d5c8065
#  9 / 19 pair: 0x6d134d63417dc67f57dbc9fcaad4b4cbfab3af2f
# 10 / 19 pair: 0x6d87359b1e3fd852bd36250018e3328d1afd78e7
# 11 / 19 pair: 0x9606d683d03f012dda296ef0ae9261207c4a5847
# 12 / 19 pair: 0x98c8cc0e444ce7490926a6c58484b937cf60e117
# 13 / 19 pair: 0x9fe4c0ce5f533e96c2b72d852f190961ad5a7bb3
# 14 / 19 pair: 0xbaf1b2fd16f7294ca158b3f1065e5f27f9c72b61
# 15 / 19 pair: 0xd061c6586670792331e14a80f3b3bb267189c681
# 16 / 19 pair: 0xd14dd3c56d9bc306322d4cea0e1c49e9ddf045d4
# 17 / 19 pair: 0xd3a0c65e5cefcee01fe2b10d04e7c16ea36974de
# 18 / 19 pair: 0xdbc490b47508d31c9ec44afb6e132ad01c61a02c
# 19 / 19 pair: 0xe7e90f5a767406eff87fdad7eb07ef407922ec1d
#                          dailyVolumeUSD        date  \
# 0    28210.7360787049979815680294217629  1624060800
# 1   28234.52255019068855675994163701818  1623974400
# 2   45731.32970840973351778782213441872  1623888000
# 3   13191.55273750856377741335732310653  1623801600
# 4   22530.38933803720187802103826302056  1623715200
# ..                                  ...         ...
# 2    1057237.32792032237233483895054982  1623888000
# 3    603765.876257862717981704745722631  1623801600
# 4   596014.2240938643283064463633435821  1623715200
# 5   706128.2949151509962194467541889058  1623628800
# 6   731263.2006899456723966942993256599  1623542400
#
#                              reserveUSD  \
# 0   635394.2683036059688112701531773593
# 1   602948.9834179958054908427556955698
# 2    656317.811908282891644527329123685
# 3   637236.6478124410544370373014081818
# 4   713754.7732246866747651528403425254
# ..                                  ...
# 2   2221636.954210931399114326060566159
# 3     2069496.6894562425845535934344946
# 4    2147812.79341156754345674350111424
# 5   2137666.226853373752370636615373126
# 6   2168416.601701943775630337744805431
#
#                                             id
# 0   0x040dd0d0f5e2a01feb0c5457abb588b23cf4c43a
# 1   0x040dd0d0f5e2a01feb0c5457abb588b23cf4c43a
# 2   0x040dd0d0f5e2a01feb0c5457abb588b23cf4c43a
# 3   0x040dd0d0f5e2a01feb0c5457abb588b23cf4c43a
# 4   0x040dd0d0f5e2a01feb0c5457abb588b23cf4c43a
# ..                                         ...
# 2   0xe7e90f5a767406eff87fdad7eb07ef407922ec1d
# 3   0xe7e90f5a767406eff87fdad7eb07ef407922ec1d
# 4   0xe7e90f5a767406eff87fdad7eb07ef407922ec1d
# 5   0xe7e90f5a767406eff87fdad7eb07ef407922ec1d
# 6   0xe7e90f5a767406eff87fdad7eb07ef407922ec1d
#
# [117 rows x 4 columns]

# %%
df5 = df4.merge(df_spirit_filtered,
                left_on = 'id',
                right_on = 'id',
                how = 'left',
                validate = 'many_to_one')
df5[['dailyVolumeUSD','reserveUSD']] = df5[['dailyVolumeUSD','reserveUSD']].astype(float)
df5['date'] = pd.to_datetime(df5['date'], unit='s')
df5['fee'] = round(df5['dailyVolumeUSD'] * 0.003,6)
df5['1y APR for 100 invested'] = round((100/df5['reserveUSD']) * df5['fee'] * 365,3)
df5['Pair'] = '[Spirit FTM] ' + df5['Pair']
df5.style.format({'reserveUSD': "{:0<4,.10f}"})
# Out:
# <style  type="text/css" >
# </style><table id="T_0a311_" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >dailyVolumeUSD</th>        <th class="col_heading level0 col1" >date</th>        <th class="col_heading level0 col2" >reserveUSD</th>        <th class="col_heading level0 col3" >id</th>        <th class="col_heading level0 col4" >Pair</th>        <th class="col_heading level0 col5" >Token 0</th>        <th class="col_heading level0 col6" >Token 1</th>        <th class="col_heading level0 col7" >fee</th>        <th class="col_heading level0 col8" >1y APR for 100 invested</th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_0a311_level0_row0" class="row_heading level0 row0" >0</th>
#                         <td id="T_0a311_row0_col0" class="data row0 col0" >28210.736079</td>
#                         <td id="T_0a311_row0_col1" class="data row0 col1" >2021-06-19 00:00:00</td>
#                         <td id="T_0a311_row0_col2" class="data row0 col2" >635,394.2683036060</td>
#                         <td id="T_0a311_row0_col3" class="data row0 col3" >0x040dd0d0f5e2a01feb0c5457abb588b23cf4c43a</td>
#                         <td id="T_0a311_row0_col4" class="data row0 col4" >[Spirit FTM] WFTM-CREAM</td>
#                         <td id="T_0a311_row0_col5" class="data row0 col5" >WFTM</td>
#                         <td id="T_0a311_row0_col6" class="data row0 col6" >CREAM</td>
#                         <td id="T_0a311_row0_col7" class="data row0 col7" >84.632208</td>
#                         <td id="T_0a311_row0_col8" class="data row0 col8" >4.862000</td>
#             </tr>
#             <tr>
#                         <th id="T_0a311_level0_row1" class="row_heading level0 row1" >1</th>
#                         <td id="T_0a311_row1_col0" class="data row1 col0" >28234.522550</td>
#                         <td id="T_0a311_row1_col1" class="data row1 col1" >2021-06-18 00:00:00</td>
#                         <td id="T_0a311_row1_col2" class="data row1 col2" >602,948.9834179959</td>
#                         <td id="T_0a311_row1_col3" class="data row1 col3" >0x040dd0d0f5e2a01feb0c5457abb588b23cf4c43a</td>
#                         <td id="T_0a311_row1_col4" class="data row1 col4" >[Spirit FTM] WFTM-CREAM</td>
#                         <td id="T_0a311_row1_col5" class="data row1 col5" >WFTM</td>
#                         <td id="T_0a311_row1_col6" class="data row1 col6" >CREAM</td>
#                         <td id="T_0a311_row1_col7" class="data row1 col7" >84.703568</td>
#                         <td id="T_0a311_row1_col8" class="data row1 col8" >5.128000</td>
#             </tr>
#             <tr>
#                         <th id="T_0a311_level0_row2" class="row_heading level0 row2" >2</th>
#                         <td id="T_0a311_row2_col0" class="data row2 col0" >45731.329708</td>
#                         <td id="T_0a311_row2_col1" class="data row2 col1" >2021-06-17 00:00:00</td>
#                         <td id="T_0a311_row2_col2" class="data row2 col2" >656,317.8119082829</td>
#                         <td id="T_0a311_row2_col3" class="data row2 col3" >0x040dd0d0f5e2a01feb0c5457abb588b23cf4c43a</td>
#                         <td id="T_0a311_row2_col4" class="data row2 col4" >[Spirit FTM] WFTM-CREAM</td>
#                         <td id="T_0a311_row2_col5" class="data row2 col5" >WFTM</td>
#                         <td id="T_0a311_row2_col6" class="data row2 col6" >CREAM</td>
#                         <td id="T_0a311_row2_col7" class="data row2 col7" >137.193989</td>
#                         <td id="T_0a311_row2_col8" class="data row2 col8" >7.630000</td>
#             </tr>
#             <tr>
#                         <th id="T_0a311_level0_row3" class="row_heading level0 row3" >3</th>
#                         <td id="T_0a311_row3_col0" class="data row3 col0" >13191.552738</td>
#                         <td id="T_0a311_row3_col1" class="data row3 col1" >2021-06-16 00:00:00</td>
#                         <td id="T_0a311_row3_col2" class="data row3 col2" >637,236.6478124411</td>
#                         <td id="T_0a311_row3_col3" class="data row3 col3" >0x040dd0d0f5e2a01feb0c5457abb588b23cf4c43a</td>
#                         <td id="T_0a311_row3_col4" class="data row3 col4" >[Spirit FTM] WFTM-CREAM</td>
#                         <td id="T_0a311_row3_col5" class="data row3 col5" >WFTM</td>
#                         <td id="T_0a311_row3_col6" class="data row3 col6" >CREAM</td>
#                         <td id="T_0a311_row3_col7" class="data row3 col7" >39.574658</td>
#                         <td id="T_0a311_row3_col8" class="data row3 col8" >2.267000</td>
#             </tr>
#             <tr>
#                         <th id="T_0a311_level0_row4" class="row_heading level0 row4" >4</th>
#                         <td id="T_0a311_row4_col0" class="data row4 col0" >22530.389338</td>
#                         <td id="T_0a311_row4_col1" class="data row4 col1" >2021-06-15 00:00:00</td>
#                         <td id="T_0a311_row4_col2" class="data row4 col2" >713,754.7732246866</td>
#                         <td id="T_0a311_row4_col3" class="data row4 col3" >0x040dd0d0f5e2a01feb0c5457abb588b23cf4c43a</td>
#                         <td id="T_0a311_row4_col4" class="data row4 col4" >[Spirit FTM] WFTM-CREAM</td>
#                         <td id="T_0a311_row4_col5" class="data row4 col5" >WFTM</td>
#                         <td id="T_0a311_row4_col6" class="data row4 col6" >CREAM</td>
#                         <td id="T_0a311_row4_col7" class="data row4 col7" >67.591168</td>
#                         <td id="T_0a311_row4_col8" class="data row4 col8" >3.456000</td>
#             </tr>
#             <tr>
#                         <th id="T_0a311_level0_row5" class="row_heading level0 row5" >5</th>
#                         <td id="T_0a311_row5_col0" class="data row5 col0" >31662.812234</td>
#                         <td id="T_0a311_row5_col1" class="data row5 col1" >2021-06-14 00:00:00</td>
#                         <td id="T_0a311_row5_col2" class="data row5 col2" >724,962.1797631354</td>
#                         <td id="T_0a311_row5_col3" class="data row5 col3" >0x040dd0d0f5e2a01feb0c5457abb588b23cf4c43a</td>
#                         <td id="T_0a311_row5_col4" class="data row5 col4" >[Spirit FTM] WFTM-CREAM</td>
#                         <td id="T_0a311_row5_col5" class="data row5 col5" >WFTM</td>
#                         <td id="T_0a311_row5_col6" class="data row5 col6" >CREAM</td>
#                         <td id="T_0a311_row5_col7" class="data row5 col7" >94.988437</td>
#                         <td id="T_0a311_row5_col8" class="data row5 col8" >4.782000</td>
#             </tr>
#             <tr>
#                         <th id="T_0a311_level0_row6" class="row_heading level0 row6" >6</th>
#                         <td id="T_0a311_row6_col0" class="data row6 col0" >21466.656609</td>
#                         <td id="T_0a311_row6_col1" class="data row6 col1" >2021-06-13 00:00:00</td>
#                         <td id="T_0a311_row6_col2" class="data row6 col2" >724,183.9673958843</td>
#                         <td id="T_0a311_row6_col3" class="data row6 col3" >0x040dd0d0f5e2a01feb0c5457abb588b23cf4c43a</td>
#                         <td id="T_0a311_row6_col4" class="data row6 col4" >[Spirit FTM] WFTM-CREAM</td>
#                         <td id="T_0a311_row6_col5" class="data row6 col5" >WFTM</td>
#                         <td id="T_0a311_row6_col6" class="data row6 col6" >CREAM</td>
#                         <td id="T_0a311_row6_col7" class="data row6 col7" >64.399970</td>
#                         <td id="T_0a311_row6_col8" class="data row6 col8" >3.246000</td>
#             </tr>
#             <tr>
#                         <th id="T_0a311_level0_row7" class="row_heading level0 row7" >7</th>
#                         <td id="T_0a311_row7_col0" class="data row7 col0" >93894.149876</td>
#                         <td id="T_0a311_row7_col1" class="data row7 col1" >2021-06-19 00:00:00</td>
#                         <td id="T_0a311_row7_col2" cla

# %%
criteria1 = df5['reserveUSD'] > 1
criteria2 = df5['date'] == df5['date'].max()

latest_results = df5.loc[(criteria1 & criteria2), :].sort_values(by = 'date',
                                 ascending = False)\
                    .drop_duplicates(subset = ['Pair'])\
                    .sort_values(by = '1y APR for 100 invested',
                                 ascending = False)\
                    .reset_index(drop = True)\
                    .drop(columns = ['id', 'Token 0', 'Token 1'])\
                    .reset_index(drop = True)[['date', 'Pair', '1y APR for 100 invested',  'reserveUSD', 'dailyVolumeUSD', 'fee']]

df_styled  = latest_results.style.format({'reserveUSD': "{:0<4,.2f}",
                             'dailyVolumeUSD': "{:0<4,.2f}",
                             'fee': "{:0<4,.2f}",
                             '1y APR for 100 invested': "{:0<4,.2f}"})\
              .set_properties(subset=["Pair"], **{'text-align': 'left'})

df_styled
# Out:
# <style  type="text/css" >
# #T_200cd_row0_col1,#T_200cd_row1_col1,#T_200cd_row2_col1,#T_200cd_row3_col1,#T_200cd_row4_col1,#T_200cd_row5_col1,#T_200cd_row6_col1,#T_200cd_row7_col1,#T_200cd_row8_col1,#T_200cd_row9_col1,#T_200cd_row10_col1,#T_200cd_row11_col1,#T_200cd_row12_col1,#T_200cd_row13_col1,#T_200cd_row14_col1{
#             text-align:  left;
#         }</style><table id="T_200cd_" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >date</th>        <th class="col_heading level0 col1" >Pair</th>        <th class="col_heading level0 col2" >1y APR for 100 invested</th>        <th class="col_heading level0 col3" >reserveUSD</th>        <th class="col_heading level0 col4" >dailyVolumeUSD</th>        <th class="col_heading level0 col5" >fee</th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_200cd_level0_row0" class="row_heading level0 row0" >0</th>
#                         <td id="T_200cd_row0_col0" class="data row0 col0" >2021-06-19 00:00:00</td>
#                         <td id="T_200cd_row0_col1" class="data row0 col1" >[Spirit FTM] WFTM-DAI</td>
#                         <td id="T_200cd_row0_col2" class="data row0 col2" >256.56</td>
#                         <td id="T_200cd_row0_col3" class="data row0 col3" >258.76</td>
#                         <td id="T_200cd_row0_col4" class="data row0 col4" >606.27</td>
#                         <td id="T_200cd_row0_col5" class="data row0 col5" >1.82</td>
#             </tr>
#             <tr>
#                         <th id="T_200cd_level0_row1" class="row_heading level0 row1" >1</th>
#                         <td id="T_200cd_row1_col0" class="data row1 col0" >2021-06-19 00:00:00</td>
#                         <td id="T_200cd_row1_col1" class="data row1 col1" >[Spirit FTM] USDC-WFTM</td>
#                         <td id="T_200cd_row1_col2" class="data row1 col2" >35.76</td>
#                         <td id="T_200cd_row1_col3" class="data row1 col3" >2,505,465.33</td>
#                         <td id="T_200cd_row1_col4" class="data row1 col4" >818,154.01</td>
#                         <td id="T_200cd_row1_col5" class="data row1 col5" >2,454.46</td>
#             </tr>
#             <tr>
#                         <th id="T_200cd_level0_row2" class="row_heading level0 row2" >2</th>
#                         <td id="T_200cd_row2_col0" class="data row2 col0" >2021-06-19 00:00:00</td>
#                         <td id="T_200cd_row2_col1" class="data row2 col1" >[Spirit FTM] DAI-FUSD</td>
#                         <td id="T_200cd_row2_col2" class="data row2 col2" >33.78</td>
#                         <td id="T_200cd_row2_col3" class="data row2 col3" >1,582.08</td>
#                         <td id="T_200cd_row2_col4" class="data row2 col4" >488.10</td>
#                         <td id="T_200cd_row2_col5" class="data row2 col5" >1.46</td>
#             </tr>
#             <tr>
#                         <th id="T_200cd_level0_row3" class="row_heading level0 row3" >3</th>
#                         <td id="T_200cd_row3_col0" class="data row3 col0" >2021-06-19 00:00:00</td>
#                         <td id="T_200cd_row3_col1" class="data row3 col1" >[Spirit FTM] fUSDT-WFTM</td>
#                         <td id="T_200cd_row3_col2" class="data row3 col2" >22.40</td>
#                         <td id="T_200cd_row3_col3" class="data row3 col3" >959,094.90</td>
#                         <td id="T_200cd_row3_col4" class="data row3 col4" >196,203.71</td>
#                         <td id="T_200cd_row3_col5" class="data row3 col5" >588.61</td>
#             </tr>
#             <tr>
#                         <th id="T_200cd_level0_row4" class="row_heading level0 row4" >4</th>
#                         <td id="T_200cd_row4_col0" class="data row4 col0" >2021-06-19 00:00:00</td>
#                         <td id="T_200cd_row4_col1" class="data row4 col1" >[Spirit FTM] USDC-FUSD</td>
#                         <td id="T_200cd_row4_col2" class="data row4 col2" >10.97</td>
#                         <td id="T_200cd_row4_col3" class="data row4 col3" >41,273.01</td>
#                         <td id="T_200cd_row4_col4" class="data row4 col4" >4,134.99</td>
#                         <td id="T_200cd_row4_col5" class="data row4 col5" >12.40</td>
#             </tr>
#             <tr>
#                         <th id="T_200cd_level0_row5" class="row_heading level0 row5" >5</th>
#                         <td id="T_200cd_row5_col0" class="data row5 col0" >2021-06-19 00:00:00</td>
#                         <td id="T_200cd_row5_col1" class="data row5 col1" >[Spirit FTM] WFTM-FUSD</td>
#                         <td id="T_200cd_row5_col2" class="data row5 col2" >8.69</td>
#                         <td id="T_200cd_row5_col3" class="data row5 col3" >83,957.13</td>
#                         <td id="T_200cd_row5_col4" class="data row5 col4" >6,661.47</td>
#                         <td id="T_200cd_row5_col5" class="data row5 col5" >19.98</td>
#             </tr>
#             <tr>
#                         <th id="T_200cd_level0_row6" class="row_heading level0 row6" >6</th>
#                         <td id="T_200cd_row6_col0" class="data row6 col0" >2021-06-19 00:00:00</td>
#                         <td id="T_200cd_row6_col1" class="data row6 col1" >[Spirit FTM] WFTM-YFI</td>
#                         <td id="T_200cd_row6_col2" class="data row6 col2" >8.60</td>
#                         <td id="T_200cd_row6_col3" class="data row6 col3" >1,253,652.94</td>
#                         <td id="T_200cd_row6_col4" class="data row6 col4" >98,403.20</td>
#                         <td id="T_200cd_row6_col5" class="data row6 col5" >295.21</td>
#             </tr>
#             <tr>
#                         <th id="T_200cd_level0_row7" class="row_heading level0 row7" >7</th>
#                         <td id="T_200cd_row7_col0" class="data row7 col0" >2021-06-19 00:00:00</td>
#                         <td id="T_200cd_row7_col1" class="data row7 col1" >[Spirit FTM] WFTM-ETH</td>
#                         <td id="T_200cd_row7_col2" class="data row7 col2" >8.24</td>
#                         <td id="T_200cd_row7_col3" class="data row7 col3" >4,625,034.69</td>
#                         <td id="T_200cd_row7_col4" class="data row7 col4" >347,922.73</td>
#                         <td id="T_200cd_row7_col5" class="data row7 col5" >1,043.77</td>
#             </tr>
#             <tr>
#                         <th id="T_200cd_level0_row8" class="row_heading level0 row8" >8</th>
#                         <td id="T_200cd_row8_col0" class="data row8 col0" >2021-06-19 00:00:00</td>
#                         <td id="T_200cd_row8_col1" class="data row8 col1" >[Spirit FTM] WFTM-CREAM</td>
#                         <td id="T_200cd_row8_col2" class="data row8 col2" >4.86</td>
#                         <td id="T_200cd_row8_col3" class="data row8 col3" >635,394.27</td>
#                         <td id="T_200cd_row8_col4" class="data row8 col4" >28,210.74</td>
#                         <td id="T_200cd_row8_col5" class="data row8 col5" >84.63</td>
#             </tr>
#             <tr>
#                         <th id="T_200cd_level0_row9" class="row_heading level0 row9" >9</th>
#                         <td id="T_200cd_row9_col0" class="data row9 col0" >2021-06-19 00:00:00</td>
#                         <td id="T_200cd_row9_col1" class="data row9 col1" >[Spirit FTM] WFTM-BTC</td>
#                         <td id="T_200cd_row9_col2" class="data row9 col2" >4.81</td>
#                         <td id="T_200cd_row9_col3" class="data row9 col3" >2,139,037.95</td>
#                         <td id="T_200cd_row9_col4" class="data row9 col4" >93,894.15</td>
#                         <td id="T_200cd_row9_col5" class="data row9 col5" >281.68</td>
#             </tr>
#             <tr>
#                         <th id="T_200cd_level0_row10" class="row_heading level0 row10" >10</th>
#                         <td id="T_200cd_row10_col0" class="data row10 col0" >2021-06-19 00:00:00</td>
#                         <td id="T_200cd_row10_col1" class="data row10 col1" >[Spirit FTM] USDC-BTC</td>

# %%
dfi.export(df_styled, 'df_styled_spooky_fantom.png')
os.startfile('df_styled_spooky_fantom.png')

# %%
# ['WFTM', 'USDC', 'DAI', 'FUSD', 'ETH', 'fUSDT', 'FETH']


# hyperswap fantom   https://ftm-info.hyperjump.fi/pairs
# honeyswap polygon  https://info.honeyswap.org/#/pairs
